# %% [markdown]
# # Online RL Figures (GPU 2)
#
# Runs online RL figures (end-to-end visitation, convergence, hyperparameter sweep, Spearman) and saves to Google Drive.

# %%
import os
from getpass import getpass

# ---- GPU selection ----
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# ---- Clone or update repo ----
if not os.path.exists("/content/temporal_invariance"):
    user = input("GitHub Username: ")
    token = getpass("GitHub Token (classic PAT with 'repo' scope): ")
    # !git clone https://{user}:{token}@github.com/{user}/temporal_invariance.git /content/temporal_invariance

# %cd /content/temporal_invariance
# !git pull

# ---- Mount Google Drive ----
from google.colab import drive

try:
    drive.mount('/content/drive', force_remount=True)
except Exception as e:
    print(f"Drive mount failed: {e}")

# ---- Install dependencies ----
# %pip install -r requirements.txt
# %pip install -e .

# ---- Run figure suite ----
# !python3 scripts/run_figures.py --config configs/colab_drive_online.yaml
