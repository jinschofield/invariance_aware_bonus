# %% [markdown]
# # Rep Figures (GPU 0)
#
# Runs the offline representation figure suite (rep sweep, t-SNE, CRTR convergence, etc.) and saves outputs to Google Drive.

# %%
import os
from getpass import getpass

# ---- GPU selection ----
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# ---- Clone or update repo ----
if not os.path.exists("/content/temporal_invariance"):
    user = input("GitHub Username: ")
    token = getpass("GitHub Token (classic PAT with 'repo' scope): ")
    # !git clone https://{user}:{token}@github.com/{user}/temporal_invariance.git /content/temporal_invariance

# %cd /content/temporal_invariance
# !git pull

# ---- Mount Google Drive ----
from google.colab import drive

# Use force_remount to trigger auth prompt if needed
try:
    drive.mount('/content/drive', force_remount=True)
except Exception as e:
    print(f"Drive mount failed: {e}")

# ---- Install dependencies ----
# %pip install -r requirements.txt
# %pip install -e .

# ---- Run figure suite ----
# !python3 scripts/run_figures.py --config configs/colab_drive_rep.yaml
# Out:
# Cloning into '/content/temporal_invariance'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 69 (delta 2), reused 69 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 54.26 KiB | 27.13 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/temporal_invariance
# Already up to date.
# Drive mount failed: mount failed
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 36.2 MB/s eta 0:00:00
# ...
# Obtaining file:///content/temporal_invariance
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for temporal-invariance (pyproject.toml) ... done
# ...
